# %%
import cv2
import matplotlib.pyplot as plt
from PIL import Image

im = Image.open("./Data/valid/45.png")

# %%
plt.imshow(im)

# %%
import numpy as np

arr = np.array(im)
arr = cv2.cvtColor(arr, cv2.COLOR_BGR2RGB)
cv2.imwrite("./Data/valid/45.JPG",arr)
# Out:
# True
